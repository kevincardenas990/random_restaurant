# %% [markdown]
# https ://maps.googleapis.com/maps/api/place/findplacefromtext/json?
#
# - fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry
# - &input=Museum%20of%20Contemporary%20Art%20Australia
# - &inputtype=textquery
# - &key=AIzaSyBe33L7Etyg7QZFdEfqOyHgvuqLh2Ul0yE
#
# ##### Query string Breakdown:
# ##### FIELDS: Asking what you would like to return
# ##### INPUT: What to search for
# ##### INPUTTYPE: What is it expecting
# ##### KEY: API key
#
# Please note if you add &2Cphotos into fields it will return a photo of the place

# %%
"""
This calls a specific place with name in the URL 
"""

from googlesearch import search
import urllib
from bs4 import BeautifulSoup
from constants import KEY
import json

URL = r"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&input=Museum%20of%20Contemporary%20Art%20Australia&inputtype=textquery&key=AIzaSyBe33L7Etyg7QZFdEfqOyHgvuqLh2Ul0yE"

thepage = urllib.request.urlopen(URL) # Produces a request object
soup = BeautifulSoup(thepage, "html.parser") # Takes Request and puts it into bs4 Object
site_json = json.loads(soup.text) # Turns Bs4 Obj into txt into Dict
print(site_json["candidates"][0]["formatted_address"])
# print(soup.prettify())

# %% [markdown]
# https ://maps.googleapis.com/maps/api/place/findplacefromtext/json
# - ?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry
# - &input=mongolian
# - &inputtype=textquery
# - &locationbias=circle%3A2000%4047.6918452%2C-122.2226413
# - &key=YOUR_API_KEY
#
# ##### Query string Breakdown:
# ##### FIELDS: Asking what you would like to return
# ##### INPUT: What to search for
# ##### INPUTTYPE: What is it expecting
# ##### LOCATIONBIAS: Asking the radius to search around a coordinate
# ##### KEY: API key
#
# Note %2C stands for , so its saying: name,rating,opening_hours,geometry\
# Note: %40 Stands for @ so its saying: @47.6918452,-122.2226413

# %%
"""
This calls a specific place with name in the URL 
"""

from googlesearch import search
import urllib
from bs4 import BeautifulSoup
from constants import KEY
import json
URL = r"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&input=mongolian&inputtype=textquery&locationbias=circle%3A2000%4047.6918452%2C-122.2226413&key=AIzaSyBe33L7Etyg7QZFdEfqOyHgvuqLh2Ul0yE"

thepage = urllib.request.urlopen(URL) # Produces a request object
soup = BeautifulSoup(thepage, "html.parser") # Takes Request and puts it into bs4 Object
site_json = json.loads(soup.text) # Turns Bs4 Obj into txt into Dict
# print(site_json["candidates"][0]["formatted_address"])
print(soup.prettify())
# Out:
# {
#    "candidates" :
#    [
#       {
#          "formatted_address" : "Mongolia",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 46.862496,
#                "lng" : 103.846656
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 52.148355,
#                   "lng" : 119.9315098
#                },
#                "southwest" :
#                {
#                   "lat" : 41.581833,
#                   "lng" : 87.7344789
#                }
#             }
#          },
#          "name" : "Mongolia"
#       }
#    ],
#    "status" : "OK"
# }

# %%
from googlesearch import search
import urllib
from bs4 import BeautifulSoup
from constants import KEY, FINDTEXTURL, TESTURL, NEARBYURL
import json
from google_maps import G_Directions

class G_Places():   
    def __init__(self, place:str, location=None, radius="50") -> None:
        self.place = place
        self._orem_coord = r"circle%3A100%4040.2788%2C111.7154"
        self.location= self._orem_coord #Change to the initializer 
        self.URL = NEARBYURL
        self._af_coord = r"circle%3A100%4040.3669331%2C-111.7771494"
        self.known_good =r"circle%3A2000%4047.6918452%2C-122.2226413"
        self.initialize_class()

    def initialize_class(self): 
        if not self.location: #Decide if we use AF or OR 
            self.location = self._orem_coord 
        self.query_string = {
            "fields":"formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry%2Cphotos",
            "input":self.place,
            "inputtype":"textquery",
            "locationbias":self._af_coord,
            "key":KEY,
            }
        self.json = self.get_json()
        self.initialize_info()
        self.GD = G_Directions("818 E 500 s AF UT", self.address)
        self.travel_time()
        self.print_cadidates()

    def print_cadidates(self):
        counter = 1
        for i in self.json["candidates"]:
            print(counter)
            counter+=1

    def travel_time(self):
        if self.validate_response():
            print(self.GD.get_arrival_time())
        # print(self.json)

    def format_query_string(self):
        new_query = self.URL
        for i in self.query_string.keys():
            new_query += f"&{i}={self.query_string[i]}"
        return new_query
    
    def get_json(self):  
        soup = BeautifulSoup(urllib.request.urlopen(self.format_query_string()), "html.parser") 
        return json.loads(soup.text) 

    def validate_response(self):
        if len(self.json["candidates"]) != 0:
            return True
        print("VALIDATION FAILED <GPLACES>")
        return False 
    
    def initialize_info (self):
        if self.validate_response():
            self.name  = self.json["candidates"][0]["name"]
            self.address = self.json["candidates"][0]["formatted_address"]
            return

        return None

# print(G_Places("restaurant"))


def test():
    BeautifulSoup(TESTURL,"html.parser")
